# %% [markdown]
# # PARCIAL # 2 - ESTEBAN CABRERA AREVALO 17781

# %% [markdown]
# CARGA SQL

# %%
# %load_ext sql

# %% [markdown]
# CARGA DE BASE DE DATOS

# %%
sql sqlite:///parcialDatos.db
# Out:
# 'Connected: @parcialDatos.db'

# %%
# %sql SELECT * FROM cliente WHERE idCliente = "503209";
# Out:
#  * sqlite:///parcialDatos.db
# Done.
# [('973719', '702626', '132061', 9363.0, '9/3/2013'),
#  ('571113', '250883', '711087', 1535.0, '14/9/2017'),
#  ('127353', '503209', '387746', 7281.0, '17/7/2018'),
#  ('621635', '175412', '879558', 5589.0, '19/7/2015'),
#  ('598146', '513096', '328614', 1203.0, '7/9/2018'),
#  ('379086', '754085', '83023', 2971.0, '26/8/2015'),
#  ('47594', '907771', '344622', 9465.0, '6/7/2016'),
#  ('344375', '754085', '887933', 3788.0, '15/8/2014'),
#  ('338406', '169087', '887933', 9335.0, '6/9/2016'),
#  ('948509', '422532', '548711', 2560.0, '0/11/2015'),
#  ('615436', '503322', '987793', 992.0, '11/4/2018'),
#  ('62829', '34728', '258630', 6756.0, '11/1/2013'),
#  ('611977', '973354', '260943', 6709.0, '5/5/2018'),
#  ('538984', '360420', '204252', 263.0, '26/7/2018'),
#  ('18997', '220766', '48463', 2409.0, '26/8/2014'),
#  ('257497', '790075', '480963', 1176.0, '7/11/2017'),
#  ('566968', '879801', '39891', 8844.0, '1/12/2013'),
# ...
